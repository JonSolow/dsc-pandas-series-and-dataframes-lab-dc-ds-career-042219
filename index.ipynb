# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#Your code here
df.columns = df.columns.str.lower()
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
#Your code here
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# ## Painstakingly change the index back

# %%
# Your code here
df = df.reset_index()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
# Your code here

df['Num_Lines'] = df.linename.map(len)
df = df.sort_values(by='Num_Lines', ascending=False)
df.head()
# Out:
#             linename   c/a  unit       scp         station division  \
# 132292  1237ACENQRSW  R151  R033  00-00-00  TIMES SQ-42 ST      IRT
# 2686    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2673    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2674    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2675    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
#
#               date      time     desc  entries  \
# 132292  08/30/2018  00:00:00  REGULAR  1417952
# 2686    08/29/2018  16:00:00  REGULAR  2836145
# 2673    08/27/2018  16:00:00  REGULAR  2830710
# 2674    08/27/2018  20:00:00  REGULAR  2832048
# 2675    08/28/2018  00:00:00  REGULAR  2832325
#
#         exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
#
#         Num_Lines
# 132292         12
# 2686           12
# 2673           12
# 2674           12
# 2675           12

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.lower()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'num_lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df['date'] = pd.to_datetime(df['date'])
df['DayOfWeek'] = df['date'].dt.dayofweek

df_grouped = df.groupby('DayOfWeek')
df_grouped.head()
# Out:
#             linename   c/a  unit       scp         station division  \
# 132292  1237ACENQRSW  R151  R033  00-00-00  TIMES SQ-42 ST      IRT
# 2686    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2673    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2674    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2675    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2676    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2677    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2678    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2679    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2682    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2683    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2684    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2685    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2702    ACENQRS1237W  A021  R032  01-00-02  TIMES SQ-42 ST      BMT
# 2688    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2689    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2690    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2691    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2695    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2696    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2697    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2698    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2699    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2672    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2671    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2670    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2657    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2658    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2659    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2660    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2663    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2664    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2665    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2666    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2667    ACENQRS1237W  A021  R032  01-00-01  TIMES SQ-42 ST      BMT
#
#              date      time     desc  entries  \
# 132292 2018-08-30  00:00:00  REGULAR  1417952
# 2686   2018-08-29  16:00:00  REGULAR  2836145
# 2673   2018-08-27  16:00:00  REGULAR  2830710
# 2674   2018-08-27  20:00:00  REGULAR  2832048
# 2675   2018-08-28  00:00:00  REGULAR  2832325
# 2676   2018-08-28  04:00:00  REGULAR  2832359
# 2677   2018-08-28  08:00:00  REGULAR  2832561
# 2678   2018-08-28  09:57:08  REGULAR  2832815
# 2679   2018-08-28  12:00:00  REGULAR  2832994
# 2682   2018-08-29  00:00:00  REGULAR  2835069
# 2683   2018-08-29  04:00:00  REGULAR  2835109
# 2684   2018-08-29  08:00:00  REGULAR  2835310
# 2685   2018-08-29  12:00:00  REGULAR  2835721
# 2702   2018-08-25  04:00:00  REGULAR  1965089
# 2688   2018-08-30  00:00:00  REGULAR  2837721
# 2689   2018-08-30  04:00:00  REGULAR  2837752
# 2690   2018-08-30  08:00:00  REGULAR  2837924
# 2691   2018-08-30  08:49:06  REGULAR  2838018
# 2695   2018-08-31  00:00:00  REGULAR  2840336
# 2696   2018-08-31  04:00:00  REGULAR  2840375
# 2697   2018-08-31  08:00:00  REGULAR  2840537
# 2698   2018-08-31  12:00:00  REGULAR  2840895
# 2699   2018-08-31  16:00:00  REGULAR  2841591
# 2672   2018-08-27  12:00:00  REGULAR  2830283
# 2671   2018-08-27  08:00:00  REGULAR  2829901
# 2670   2018-08-27  04:00:00  REGULAR  2829717
# 2657   2018-08-25  00:00:00  REGULAR  2827885
# 2658   2018-08-25  04:00:00  REGULAR  2827938
# 2659   2018-08-25  08:00:00  REGULAR  2827968
# 2660   2018-08-25  12:00:00  REGULAR  2828124
# 2663   2018-08-26  00:00:00  REGULAR  2828942
# 2664   2018-08-26  04:00:00  REGULAR  2828982
# 2665   2018-08-26  08:00:00  REGULAR  2828995
# 2666   2018-08-26  12:00:00  REGULAR  2829107
# 2667   2018-08-26  16:00:00  REGULAR  2829296
#
#         exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
# 2676                                              3306438
# 2677                                              3306716
# 2678                                              3307705
# 2679                                              3308064
# 2682                                              3309328
# 2683                                              3309348
# 2684                                              3309579
# 2685                                              3310943
# 2702                                              1942027
# 2688                                              3312246
# 2689                                              3312261
# 2690                                              3312478
# 2691                                              3312826
# 2695                                              3315042
# 2696                                              3315061
# 2697                                              3315242
# 2698                                              3316295
# 2699                                              3316775
# 2672                                              3305370
# 2671                                              3304039
# 2670                                              3303805
# 2657                                              3301103
# 2658                                              3301128
# 2659                                              3301188
# 2660                                              3301522
# 2663                                              3302587
# 2664                                              3302615
# 2665                                              3302636
# 2666                                              3302926
# 2667                                              3303350
#
#         num_lines  DayOfWeek
# 132292         12          3
# 2686           12          2
# 2673           12          0
# 2674           12          0
# 2675           12          1
# 2676           12          1
# 2677           12          1
# 2678           12          1
# 2679           12          1
# 2682           12          2
# 2683           12          2
# 2684           12          2
# 2685           12          2
# 2702           12          5
# 2688           12          3
# 2689           12          3
# 2690           12          3
# 2691           12          3
# 2695           12          4
# 2696           12          4
# 2697           12          4
# 2698           12          4
# 2699           12          4
# 2672           12          0
# 2671           12          0
# 2670           12          0
# 2657           12          5
# 2658           12          5
# 2659           12          5
# 2660           12          5
# 2663           12          6
# 2664           12          6
# 2665           12          6
# 2666           12          6
# 2667           12          6

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes

# %%
#Your code here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
